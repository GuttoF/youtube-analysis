# %% [markdown]
# # Netflix Analysis
#
# Crisp-DM Cycle 1
#
# ---

# %% [markdown]
# ## 0. Preparation

# %% [markdown]
# ### 0.1 Imports

# %%
import pandas as pd

# %% [markdown]
# ### 0.2 Data

# %%
# Paths
homepath = '/Users/guttofranca/Repos/netflix-analysis/netflix_analysis'
datapath = homepath + '/data/raw/'

# Data

# CA
df_CA = pd.read_csv(datapath + 'CAvideos.csv', encoding='utf-8')
df_CA['country'] = 'Canada'

# DE   
df_DE = pd.read_csv(datapath + 'DEvideos.csv', encoding='utf-8')
df_DE['country'] = 'Germany'

# FR
df_FR = pd.read_csv(datapath + 'FRvideos.csv', encoding='utf-8')
df_FR['country'] = 'France'

# GB
df_GB = pd.read_csv(datapath + 'GBvideos.csv', encoding='utf-8')
df_GB['country'] = 'Great Britain'

# IN
df_IN = pd.read_csv(datapath + 'INvideos.csv', encoding='utf-8')
df_IN['country'] = 'India'

# JP
df_JP = pd.read_csv(datapath + 'JPvideos.csv', encoding='ISO-8859-1')
df_JP['country'] = 'Japan'

# KR
df_KR = pd.read_csv(datapath + 'KRvideos.csv', encoding='ISO-8859-1')
df_KR['country'] = 'South Korea'

# MX
df_MX = pd.read_csv(datapath + 'MXvideos.csv', encoding='ISO-8859-1')
df_MX['country'] = 'Mexico'

# RU
df_RU = pd.read_csv(datapath + 'RUvideos.csv', encoding='ISO-8859-1')
df_RU['country'] = 'Russia'

# US
df_US = pd.read_csv(datapath + 'USvideos.csv', encoding='utf-8')
df_US['country'] = 'United States'

# Using only utf-8 encoded files
df_raw = pd.concat([df_CA, df_DE, df_FR, df_GB, df_IN, df_US], ignore_index=True).reset_index(drop=True)

# Saving the raw data as pickle
df_raw.to_pickle(homepath + '/data/processed/df_raw.pkl')

# %% [markdown]
# ### 0.3 Functions

# %%
def fix_tags(tags):
    """
    Fixes the formatting of tags by removing extra spaces and adding double quotes.

    Args:
        tags (str): A string containing tags separated by '|'.

    Returns:
        str: A string with tags adjusted by removing extra spaces and adding double quotes.

    Example:
        >>> fix_tags("action |  comedy | drama")
        '"action" | "comedy" | "drama"'
    """

    separated_tags = tags.split('|')
    adjusted_tags = ['"' + tag.replace('"', '').strip() + '"' for tag in separated_tags]
    
    return ' | '.join(adjusted_tags)

# %% [markdown]
# ## 1. Data Description

# %%
df1 = pd.read_pickle(homepath + '/data/processed/df_raw.pkl')

# %% [markdown]
# ### 1.1 Data Dimensions

# %%
print(f'Number of rows: {df1.shape[0]} \nNumber of columns: {df1.shape[1]}')
# Out:
# Number of rows: 239662
# Number of columns: 17

# %% [markdown]
# ### 1.2 Changing Dtypes

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239662 entries, 0 to 239661
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   video_id                239662 non-null  object
#  1   trending_date           239662 non-null  object
#  2   title                   239662 non-null  object
#  3   channel_title           239662 non-null  object
#  4   category_id             239662 non-null  int64
#  5   publish_time            239662 non-null  object
#  6   tags                    239662 non-null  object
#  7   views                   239662 non-null  int64
#  8   likes                   239662 non-null  int64
#  9   dislikes                239662 non-null  int64
#  10  comment_count           239662 non-null  int64
#  11  thumbnail_link          239662 non-null  object
#  12  comments_disabled       239662 non-null  bool
#  13  ratings_disabled        239662 non-null  bool
#  14  video_error_or_removed  239662 non-null  bool
#  15  description             232159 non-null  object
#  16  country                 239662 non-null  object
# dtypes: bool(3), int64(5), object(9)
# memory usage: 26.3+ MB

# %% [markdown]
# `Data Types`
#
# `video_id` : String
#
# `trending_date`: Datetime
#
# `title`: String
#
# `channel_title`: String
#
# `category_id` : Int
#
# `publish_time`: Timestamp
#
# `tags`: String
#
# `views`: Int
#
# `likes`: Int
#
# `dislikes`: Int
#
# `comment_count`: Int
#
# `thumbnail_link`: String
#
# `comments_disabled`: Boolean
#
# `ratings_disabled`: Boolean
#
# `video_error_or_removed`: Boolean
#
# `description`: String
#
# `country`: String

# %%
# Transformations

# Changing the columns to string
columns_to_string = [['video_id', 'title', 'channel_title', 'tags', 'thumbnail_link', 'description', 'country']]

for column in columns_to_string:
    df1[column] = df1[column].astype('string')

# Changing the columns to datetime
df1['trending_date'] = pd.to_datetime(df1['trending_date'], format='%y.%d.%m')

# Changing the columns to timestamp
df1['publish_time'] = pd.to_datetime(df1['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# %%
df1.dtypes
# Out:
# video_id                  string[python]
# trending_date             datetime64[ns]
# title                     string[python]
# channel_title             string[python]
# category_id                        int64
# publish_time              datetime64[ns]
# tags                      string[python]
# views                              int64
# likes                              int64
# dislikes                           int64
# comment_count                      int64
# thumbnail_link            string[python]
# comments_disabled                   bool
# ratings_disabled                    bool
# video_error_or_removed              bool
# description               string[python]
# country                   string[python]
# dtype: object

# %% [markdown]
# ### 1.3 Fixing Inconsistences

# %%
df1.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc    2017-11-14
# 1  0dBIkQ4Mz1M    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  d380meD0W0M    2017-11-14
# 4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id        publish_time  \
# 0           10 2017-11-10 17:00:03
# 1           23 2017-11-13 17:00:00
# 2           23 2017-11-12 19:05:24
# 3           24 2017-11-12 18:01:41
# 4           10 2017-11-09 11:04:14
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description country
# 0  Eminem's new track Walk on Water ft. Beyoncé i...  Canada
# 1  STill got a lot of packages. Probably will las...  Canada
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...  Canada
# 3  I know it's been a while since we did this sho...  Canada
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...  Canada

# %%
# Replace "|" with " | " and split the last tag
df1['tags'] = df1['tags'].apply(fix_tags)

# %% [markdown]
# ### 1.4 Unique Values

# %%
df1.nunique()
# Out:
# video_id                   94007
# trending_date                205
# title                      94704
# channel_title              17798
# category_id                   18
# publish_time               86983
# tags                       74046
# views                     178399
# likes                      66911
# dislikes                   15413
# comment_count              23219
# thumbnail_link             94179
# comments_disabled              2
# ratings_disabled               2
# video_error_or_removed         2
# description                82201
# country                        6
# dtype: int64

# %% [markdown]
# ### 1.5 NULL

# %%
df1.isnull().sum()
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               7503
# country                      0
# dtype: int64

# %%
df_null_description = df1[df1['description'].isnull()]
df_null_description.head()
# Out:
#         video_id trending_date  \
# 98   lHcXhBojpeQ    2017-11-14
# 115  _QHEPUKBn9g    2017-11-14
# 128  JdHovvb0KD4    2017-11-14
# 165  OA0vhAKUD0g    2017-11-14
# 179  psDauoxUj9A    2017-11-14
#
#                                                  title channel_title  \
# 98                    三屆TVB視帝，拋棄10年青梅竹馬髮妻，為娶小三還不惜與母絕交！         明星百曉生
# 115  ‘Too Alabama for Alabama’: SNL brutally mocks ...    MAXI POWER
# 128  Pres. Trump: Putin's Denials Of Interference I...      The View
# 165            Outlander S03E09 i'm melting with you''     Ella bell
# 179  شاهد انبهار الاعلام المصري  بتأهل المغرب لكأس ...    Info Press
#
#      category_id        publish_time  \
# 98            22 2017-11-12 12:49:50
# 115           23 2017-11-12 05:01:18
# 128           25 2017-11-13 16:10:21
# 165            1 2017-11-12 22:33:48
# 179           17 2017-11-11 22:04:37
#
#                                                   tags   views  likes  \
# 98                                            "[none]"   88061     47
# 115                                           "[none]"   20163     44
# 128  "donald trump" | "vladimir putin" | "the view"...   72253   1217
# 165                                           "[none]"   32941    149
# 179                                           "[none]"  624328   7100
#
#      dislikes  comment_count                                  thumbnail_link  \
# 98         58             17  https://i.ytimg.com/vi/lHcXhBojpeQ/default.jpg
# 115        34              8  https://i.ytimg.com/vi/_QHEPUKBn9g/default.jpg
# 128       146            569  https://i.ytimg.com/vi/JdHovvb0KD4/default.jpg
# 165         2              5  https://i.ytimg.com/vi/OA0vhAKUD0g/default.jpg
# 179       398            971  https://i.ytimg.com/vi/psDauoxUj9A/default.jpg
#
#      comments_disabled  ratings_disabled  video_error_or_removed description  \
# 98               False             False                   False        <NA>
# 115              False             False                   False        <NA>
# 128              False             False                   False        <NA>
# 165              False             False                   False        <NA>
# 179              False             False                   False        <NA>
#
#     country
# 98   Canada
# 115  Canada
# 128  Canada
# 165  Canada
# 179  Canada

# %% [markdown]
# There are 7503 NA rows in the `description` column, to quick fix this, I'll replace it with a description called: No description provided.

# %%
df1['description'] = df1['description'].fillna('No description provided.')

df1.isnull().sum()
# Out:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# description               0
# country                   0
# dtype: int64

# %% [markdown]
# ### 1.6 Duplicated Values

# %%
df1.duplicated().sum()
# Out:
# 4482

# %%
df1[df1.duplicated()].head()
# Out:
#            video_id trending_date  \
# 156188  RUCXD3_wW2w    2018-05-14
# 156189  p8npDG2ulKQ    2018-05-14
# 156190  aixso4N2vhI    2018-05-14
# 156191  bu0m_UdtoaU    2018-05-14
# 156192  i-G1hy73Mb8    2018-05-14
#
#                                                     title  \
# 156188                                New Hulu Show - SNL
# 156189  BTS (방탄소년단) LOVE YOURSELF 轉 Tear 'Singularity'...
# 156190  President Trump Gives Remarks on the Joint Com...
# 156191           Serious Questions: Avengers Infinity War
# 156192  Eurovision Song Contest 2018 - Opening Ceremon...
#
#                   channel_title  category_id        publish_time  \
# 156188      Saturday Night Live           24 2018-05-13 04:59:28
# 156189                  ibighit           10 2018-05-06 15:00:02
# 156190          The White House           25 2018-05-08 18:45:37
# 156191           Screen Junkies            1 2018-05-06 17:00:03
# 156192  Eurovision Song Contest           24 2018-05-06 19:46:34
#
#                                                      tags     views    likes  \
# 156188  "SNL" | "Saturday Night Live" | "SNL Season 43...    723495     6362
# 156189  "BIGHIT" | "빅히트" | "방탄소년단" | "BTS" | "BANGTAN"...  26912663  2636004
# 156190                                           "[none]"     89715     2806
# 156191  "screenjunkies" | "screen junkies" | "serious ...    443621    12892
# 156192  "Eurovision Song Contest" | "2018" | "Lisbon" ...    698827    11721
#
#         dislikes  comment_count  \
# 156188      1589            420
# 156189     27675         366899
# 156190       488           1657
# 156191      3829           2275
# 156192       461           1175
#
#                                         thumbnail_link  comments_disabled  \
# 156188  https://i.ytimg.com/vi/RUCXD3_wW2w/default.jpg              False
# 156189  https://i.ytimg.com/vi/p8npDG2ulKQ/default.jpg              False
# 156190  https://i.ytimg.com/vi/aixso4N2vhI/default.jpg              False
# 156191  https://i.ytimg.com/vi/bu0m_UdtoaU/default.jpg              False
# 156192  https://i.ytimg.com/vi/i-G1hy73Mb8/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 156188             False                   False
# 156189             False                   False
# 156190             False                   False
# 156191             False                   False
# 156192             False                   False
#
#                                               description        country
# 156188  From the executive producer of Sex and the Cit...  Great Britain
# 156189  BTS (방탄소년단) LOVE YOURSELF 轉 Tear 'Singularity'...  Great Britain
# 156190                                    The White House  Great Britain
# 156191  After watching Avengers: Infinity War we have ...  Great Britain
# 156192  At 18:00 CEST today, the Blue Carpet ceremony ...  Great Britain

# %% [markdown]
# An example:

# %%
df1[df1['video_id'] == 'RUCXD3_wW2w']
# Out:
#            video_id trending_date                        title  \
# 156074  RUCXD3_wW2w    2018-05-14          New Hulu Show - SNL
# 156188  RUCXD3_wW2w    2018-05-14          New Hulu Show - SNL
# 156246  RUCXD3_wW2w    2018-05-15  Handmaids in the City - SNL
# 156320  RUCXD3_wW2w    2018-05-15  Handmaids in the City - SNL
# 156404  RUCXD3_wW2w    2018-05-16  Handmaids in the City - SNL
# 156552  RUCXD3_wW2w    2018-05-16  Handmaids in the City - SNL
#
#               channel_title  category_id        publish_time  \
# 156074  Saturday Night Live           24 2018-05-13 04:59:28
# 156188  Saturday Night Live           24 2018-05-13 04:59:28
# 156246  Saturday Night Live           24 2018-05-13 04:59:28
# 156320  Saturday Night Live           24 2018-05-13 04:59:28
# 156404  Saturday Night Live           24 2018-05-13 04:59:28
# 156552  Saturday Night Live           24 2018-05-13 04:59:28
#
#                                                      tags    views  likes  \
# 156074  "SNL" | "Saturday Night Live" | "SNL Season 43...   723495   6362
# 156188  "SNL" | "Saturday Night Live" | "SNL Season 43...   723495   6362
# 156246  "SNL" | "Saturday Night Live" | "SNL Season 43...  1094378   8781
# 156320  "SNL" | "Saturday Night Live" | "SNL Season 43...  1094378   8781
# 156404  "SNL" | "Saturday Night Live" | "SNL Season 43...  1250529   9870
# 156552  "SNL" | "Saturday Night Live" | "SNL Season 43...  1250529   9870
#
#         dislikes  comment_count  \
# 156074      1589            420
# 156188      1589            420
# 156246      2234            600
# 156320      2234            600
# 156404      2437            649
# 156552      2437            649
#
#                                         thumbnail_link  comments_disabled  \
# 156074  https://i.ytimg.com/vi/RUCXD3_wW2w/default.jpg              False
# 156188  https://i.ytimg.com/vi/RUCXD3_wW2w/default.jpg              False
# 156246  https://i.ytimg.com/vi/RUCXD3_wW2w/default.jpg              False
# 156320  https://i.ytimg.com/vi/RUCXD3_wW2w/default.jpg              False
# 156404  https://i.ytimg.com/vi/RUCXD3_wW2w/default.jpg              False
# 156552  https://i.ytimg.com/vi/RUCXD3_wW2w/default.jpg              False
#
#         ratings_disabled  video_error_or_removed  \
# 156074             False                   False
# 156188             False                   False
# 156246             False                   False
# 156320             False                   False
# 156404             False                   False
# 156552             False                   False
#
#                                               description        country
# 156074  From the executive producer of Sex and the Cit...  Great Britain
# 156188  From the executive producer of Sex and the Cit...  Great Britain
# 156246  From the executive producer of Sex and the Cit...  Great Britain
# 156320  From the executive producer of Sex and the Cit...  Great Britain
# 156404  From the executive producer of Sex and the Cit...  Great Britain
# 156552  From the executive producer of Sex and the Cit...  Great Britain

# %% [markdown]
# The columns are all the same in the example, so I will drop them all.

# %%
df1 = df1.drop_duplicates()
